# %% [markdown]
# # **Codes**

# %%
qualification = int(input("Enter your qualification: "))
marks = int(input("Enter your marks: "))
potential = int(input("Enter your potential: "))

w1 = 0.1
w2 = 0.1
w3 = 0.8

result = (qualification * w1) + (marks * w2) + (potential * w3)

if result > 70:
    print("You are qualified")
else:
    print("You are not qualified")
# Out:
# Enter your qualification: 2
# Enter your marks: 98
# Enter your potential: 100
# You are qualified

# %%
fruits = int(input("Enter Fruits Quantity: "))
vegetables = int(input("Enter Vegetables Quantity: "))
rice = int(input("Enter Rice Quantity: "))
oil = int(input("Enter Oil Quantity:" ))

fr_w1 = 0.34
ve_w2 = 0.23
ri_w3 = 0.30
oi_w4 = 0.13

Total = (fruits*fr_w1) + (vegetables*ve_w2) + (rice*ri_w3) + (oil*oi_w4)

if Total >90:
  print("Fruits Quantity is Maximum")
elif Total > 80:
  print("Vegetables Quantity is Maximum")
elif Total > 70:
  print("Rice Quantity is Maximum")
elif Total > 60:
  print("Oil Quantity is Maximum")
else:
  print("No Quantity is Maximum")
# Out:
# Enter Fruits Quantity: 65
# Enter Vegetables Quantity: 23
# Enter Rice Quantity: 78
# Enter Oil Quantity:54
# No Quantity is Maximum

# %%
fruits = int(input("Enter Fruits Quantity: "))
vegetables = int(input("Enter Vegetables Quantity: "))
rice = int(input("Enter Rice Quantity: "))
oil = int(input("Enter Oil Quantity:" ))
butter = int(input("Enter Butter Quantity: "))
masalah = int(input("Enter Masala Quantity: "))

fr_w1 = 0.34
ve_w2 = 0.23
ri_w3 = 0.30
oi_w4 = 0.13
bu_w5 = 0.05
ma_w6 = 0.05

Total = (fruits*fr_w1) + (vegetables*ve_w2) + (rice*ri_w3) + (oil*oi_w4) + (butter*bu_w5) + (masalah*ma_w6)

if Total >90:
  print("Fruits Quantity is Maximum")
elif Total > 80:
  print("Vegetables Quantity is Maximum")
elif Total > 70:
  print("Rice Quantity is Maximum")
elif Total > 60:
  print("Oil Quantity is Maximum")
elif Total > 50:
  print("Butter Quantity is Maximum")
elif Total > 0.45:
  print("Masala Quantity is Maximum")
else:
  print("No Quantity is Maximum")
# Out:
# Enter Fruits Quantity: 12
# Enter Vegetables Quantity: 33
# Enter Rice Quantity: 22
# Enter Oil Quantity:1
# Enter Butter Quantity: 3
# Enter Masala Quantity: 5
# Masala Quantity is Maximum

# %%
ali = int(input("Enter Ali Marks: "))
ahmed = int(input("Enter Ahmed Marks: "))
umer = int(input("Enter Umer Marks: "))
bilal = int(input("Enter Bilal Marks: "))
akhtar = int(input("Enter Akhtar Marks: "))
asif = int(input("Enter Asif Marks: "))
usman = int(input("Enter Usman Marks: "))
ahsan = int(input("Enter Ahsan Marks: "))

ali_w1 = 0.10
ahmed_w2 = 0.12
umer_w3 = 0.44
bilal_w4 = 0.55
akhtar_w5 = 0.3
asif_w6 = 0.1
usman_w7 = 0.23
ahsan_w8 = 0.12

Final_Result = (ali*ali_w1) + (ahmed*ahmed_w2) + (umer*umer_w3) + (bilal*bilal_w4) + (akhtar*akhtar_w5) + (asif*asif_w6) + (usman*usman_w7) + (ahsan*ahsan_w8)

if Final_Result > 90:
  print("Ali Has Got Highest Marks")
  print("Ali Got: ", Final_Result)
elif Final_Result > 80:
  print("Ahmed Has B Grade")
  print("Ahmed Got: ", Final_Result)
elif Final_Result > 70:
  print("Umer Has C Grade")
  print("Umer Got: ", Final_Result)
elif Final_Result > 60:
  print("Bilal Has D Grade")
  print("Bilal Got: ", Final_Result)
elif Final_Result > 50:
  print("Akhtar Has E Grade")
  print("Akhtar Got: ", Final_Result)
elif Final_Result > 40:
  print("Asif Has F Grade")
  print("Asif Got: ", Final_Result)
elif Final_Result > 30:
  print("Usman Has G Grade")
  print("Usman Got: ", Final_Result)
elif Final_Result > 20:
  print("Ahsan Has H Grade")
else:
  print("No Grade")
# Out:
# Enter Ali Marks: 94
# Enter Ahmed Marks: 67
# Enter Umer Marks: 56
# Enter Bilal Marks: 87
# Enter Akhtar Marks: 78
# Enter Asif Marks: 77
# Enter Usman Marks: 45
# Enter Ahsan Marks: 33
# Ali Has Got Highest Marks
# Ali Got:  135.34000000000003

# %%
shoib = int(input("Enter Shoib Scores: "))
akmal = int(input("Enter Akmal Scores: "))
ahsan = int(input("Enter Ahsan Scores: "))
shahid = int(input("Enter Shahid Scores: "))
amir = int(input("Enter Amir Scores: "))
misbah = int(input("Enter Misbah Scores: "))
saim = int(input("Enter Saim Scores: "))
ahmed = int(input("Enter Ahmed Scores: "))
rizwan = int(input("Enter Rizwan Scores: "))
babar = int(input("Enter Babar Scores: "))


shoib_w1 = 0.33
akmal_w2 = 0.23
ahsan_w3 = 0.9
shahid_w4 = 0.2
amir_w5 = 0.65
misbah_w6 = 0.11
saim_w7 = 0.20
ahmed_w8 = 0.4
rizwan_w9 = 0.50
babar_w10 = 0.45

Maximum_Score = (shoib*shoib_w1) + (akmal*akmal_w2) + (ahsan*ahsan_w3) + (shahid*shahid_w4) + (amir*amir_w5) + (misbah*misbah_w6) + (saim*saim_w7) + (ahmed*ahmed_w8) + (rizwan*rizwan_w9) + (babar*babar_w10)

if Maximum_Score > 150:
  print("Shoib Has Highest Score")
  print("Shoib Got: ", Maximum_Score)
elif Maximum_Score > 123:
  print("Akmal Has Highest Score")
  print("Akmal Got: ", Maximum_Score)
elif Maximum_Score > 100:
  print("Ahmed Has Century ")
  print("Ahmed Got: ", Maximum_Score)
elif Maximum_Score > 89:
  print("Shahid Has Best Score")
  print("Shahid Got: ", Maximum_Score)
elif Maximum_Score > 112:
  print("Amir Has Brilliant Score")
  print("Amir Got: ", Maximum_Score)
elif Maximum_Score > 78:
  print("Misbah Has Good Score")
  print("Misbah Got: ", Maximum_Score)
elif Maximum_Score > 67:
  print("Saim Has Average Score")
  print("Saim Got: ", Maximum_Score)
elif Maximum_Score > 56:
  print("Ahmed Has Fifty")
  print("Ahmed Got: ", Maximum_Score)
elif Maximum_Score > 45:
  print("Rizwan Has Normal Score")
  print("Rizwan Got: ", Maximum_Score)
elif Maximum_Score > 34:
  print("Babar Has Poor Score")
  print("Babar Got: ", Maximum_Score)
else:
  print("Normal Score ")
# Out:
# Enter Shoib Scores: 110
# Enter Akmal Scores: 46
# Enter Ahsan Scores: 23
# Enter Shahid Scores: 78
# Enter Amir Scores: 55
# Enter Misbah Scores: 89
# Enter Saim Scores: 135
# Enter Ahmed Scores: 56
# Enter Rizwan Scores: 99
# Enter Babar Scores: 100
# Shoib Has Highest Score
# Shoib Got:  272.62

# %%
x1 = int(input("Enter X1: "))
x2 = int(input("Enter X2: "))
x3 = int(input("Enter X3: "))
x4 = int(input("Enter X4: "))
x5 = int(input("Enter X5: "))
x6 = int(input("Enter X6: "))
x7 = int(input("Enter X7: "))
x8 = int(input("Enter X8: "))
x9 = int(input("Enter X9: "))
x10 = int(input("Enter X10: "))
x11 = int(input("Enter X11: "))
x12 = int(input("Enter X12: "))

w1 = 0.10
w2 = 0.20
w3 = 0.5
w4 = 0.14
w5 = 0.1
w6 = 0.7
w7 = 0.3
w8 = 0.25
w9 = 0.11
w10 = 0.2
w11 = 0.1
w12 = 0.1

Final = (x1*w1) + (x2*w2) + (x3*w3) + (x4*w4) + (x5*w5) + (x6*w6) + (x7*w7) + (x8*w8) + (x9*w9) + (x10*w10) + (x11*w11) + (x12*w12)

if Final > 90:
  print("X1 Has Highest Score")
  print("X1 Got: ", Final)
elif Final > 80:
  print("X2 Has Highest Score")
  print("X2 Got: ", Final)
elif Final > 70:
  print("X3 Has Highest Score")
  print("X3 Got: ", Final)
elif Final > 60:
  print("X4 Has Highest Score")
  print("X4 Got: ", Final)
elif Final > 50:
  print("X5 Has Highest Score")
  print("X5 Got: ", Final)
elif Final > 40:
  print("X6 Has Highest Score")
  print("X6 Got: ", Final)
elif Final > 30:
  print("X7 Has Highest Score")
  print("X7 Got: ", Final)
elif Final > 20:
  print("X8 Has Highest Score")
  print("X8 Got: ", Final)
elif Final > 10:
  print("X9 Has Highest Score")
  print("X9 Got: ", Final)
elif Final > 0:
  print("X10 Has Highest Score")
  print("X10 Got: ", Final)
elif Final > -10:
  print("X11 Has Highest Score")
  print("X11 Got: ", Final)
elif Final > -20:
  print("X12 Has Highest Score")
  print("X12 Got: ", Final)
else:
  print("Invalid Score")
# Out:
# Enter X1: 23
# Enter X2: 44
# Enter X3: 34
# Enter X4: 88
# Enter X5: 54
# Enter X6: 90
# Enter X7: 10
# Enter X8: 66
# Enter X9: 78
# Enter X10: 8
# Enter X11: 34
# Enter X12: 13
# X1 Has Highest Score
# X1 Got:  143.20000000000002

# %%
pencils = int(input("Enter Pencils Quantity: "))
pens = int(input("Enter Pens Quantity: "))
erasers = int(input("Enter Erasers Quantity: "))
markers = int(input("Enter Markers Quantity: "))
copies = int(input("Enter Copies Quantity: "))
notebooks = int(input("Enter Notebooks Quantity: "))
paper = int(input("Enter Paper Quantity: "))
sheets = int(input("Enter Sheets Quantity: "))
registers = int(input("Enter Registers Quantity: "))
pointers = int(input("Enter Pointers Quantity: "))
ballpoint = int(input("Enter Ballpoint Quantity: "))
shopners = int(input("Enter Shopners Quantity: "))
staplers = int(input("Enter Staplers Quantity: "))
paperclips = int(input("Enter Paperclips Quantity: "))

pencil_w1 = 0.9
pen_w2 = 0.1
eraser_w3 = 0.34
marker_w4 = 0.23
copy_w5 = 0.3
note_w6 = 0.45
pap_w7 = 0.12
shee_w8 = 0.4
reg_w9 = 0.18
poi_w10 = 0.2
bal_w11 = 0.6
sho_w12 = 0.8
sta_w13 = 0.5
p_w14 = 0.7

Stationaries = (pencils*pencil_w1) + (pens*pen_w2) + (erasers*eraser_w3) + (markers*marker_w4) + (copies*copy_w5) + (notebooks*note_w6) + (paper*pap_w7) + (sheets*shee_w8) + (registers*reg_w9) + (pointers*poi_w10) + (ballpoint*bal_w11) + (shopners*sho_w12) + (staplers*sta_w13) + (paperclips*p_w14)

if Stationaries > 90:
  print("Pencils Quantity is Maximum")
elif Stationaries > 80:
  print("Pens Quantity is Maximum")
elif Stationaries > 70:
  print("Erasers Quantity is Maximum")
elif Stationaries > 60:
  print("Markers Quantity is Maximum")
elif Stationaries > 50:
  print("Copies Quantity is Maximum")
elif Stationaries > 40:
  print("Notebooks Quantity is Maximum")
elif Stationaries > 30:
  print("Paper Quantity is Maximum")
elif Stationaries > 20:
  print("Sheets Quantity is Maximum")
elif Stationaries > 10:
  print("Registers Quantity is Maximum")
elif Stationaries > 16:
  print("Pointers Quantity is Maximum")
elif Stationaries > 15:
  print("Ballpoint Quantity is Maximum")
elif Stationaries > 56:
  print("Shopners Quantity is Maximum")
elif Stationaries > 78:
  print("Staplers Quantity is Maximum")
elif Stationaries > 23:
  print("Paperclips Quantity is Maximum")
else:
  print("No Quantity is Maximum")
# Out:
# Enter Pencils Quantity: 56
# Enter Pens Quantity: 77
# Enter Erasers Quantity: 1788
# Enter Markers Quantity: 655
# Enter Copies Quantity: 87
# Enter Notebooks Quantity: 233
# Enter Paper Quantity: 566
# Enter Sheets Quantity: 122
# Enter Registers Quantity: 155
# Enter Pointers Quantity: 175
# Enter Ballpoint Quantity: 12
# Enter Shopners Quantity: 145
# Enter Staplers Quantity: 143
# Enter Paperclips Quantity: 112
# Pencils Quantity is Maximum

# %%
carola = int(input(" Enter Carola Car Speed: "))
honda = int(input(" Enter Honda Car Speed: "))
suzuki = int(input(" Enter Suzuki Car Speed: "))
toyota = int(input(" Enter Toyota Car Speed: "))
mercedes = int(input(" Enter Mercedes Car Speed: "))
bughati = int(input(" Enter Bughati Car Speed: "))
ferrari = int(input(" Enter Ferrari Car Speed: "))
lamborghini = int(input(" Enter Lamborghini Car Speed: "))
bmw = int(input(" Enter BMW Car Speed: "))
audi = int(input(" Enter Audi Car Speed: "))
volvo = int(input(" Enter Volvo Car Speed: "))
lexus = int(input(" Enter Lexus Car Speed: "))
mini = int(input(" Enter Mini Car Speed: "))
jaguar = int(input(" Enter Jaguar Car Speed: "))
ford = int(input(" Enter Ford Car Speed: "))
chevrolet = int(input(" Enter Chevrolet Car Speed: "))

carola_w1 = 0.12
honda_w2 = 0.11
suzuki_w3 = 0.2
toyota_w4 = 0.9
mercedes_w5 = 0.23
bughati_w6 = 0.99
ferrari_w7 = 0.67
lamb_w8 = 0.78
bmw_w9 = 0.45
audi_w10 = 0.34
volvo_w11 = 0.32
lexus_w12 = 0.25
mini_w13 = 0.3
jag_w14 = 0.34
ford_w15 = 0.2
chevrolet_w16 = 0.1

Maximum_Speed = (carola*carola_w1) + (honda*honda_w2) + (suzuki*suzuki_w3) + (toyota*toyota_w4) + (mercedes*mercedes_w5) + (bughati*bughati_w6) + (ferrari*ferrari_w7) + (lamborghini*lamb_w8) + (bmw*bmw_w9) + (audi*audi_w10) + (volvo*volvo_w11) + (lexus*lexus_w12) + (mini*mini_w13) + (jaguar*jag_w14) + (ford*ford_w15) + (chevrolet*chevrolet_w16)

if Maximum_Speed > 150:
  print("Carola Has Highest Speed")
  print("Carola Got: ", Maximum_Speed)
elif Maximum_Speed > 123:
  print("Honda Has Highest Speed")
  print("Honda Got: ", Maximum_Speed)
elif Maximum_Speed > 100:
  print("Suzuki Has Highest Speed")
  print("Suzuki Got: ", Maximum_Speed)
elif Maximum_Speed > 200:
  print("Toyota Has Highest Speed")
  print("Toyota Got: ", Maximum_Speed)
elif Maximum_Speed > 220:
  print("Mercedes Has Highest Speed")
  print("Mercedes Got: ", Maximum_Speed)
elif Maximum_Speed > 500:
  print("Bughati Has Highest Speed")
  print("Bughati Got: ", Maximum_Speed)
elif Maximum_Speed > 400:
  print("Ferrari Has Highest Speed")
  print("Ferrari Got: ", Maximum_Speed)
elif Maximum_Speed > 450:
  print("Lamborghini Has Highest Speed")
  print("Lamborghini Got: ", Maximum_Speed)
elif Maximum_Speed > 300:
  print("BMW Has Highest Speed")
  print("BMW Got: ", Maximum_Speed)
elif Maximum_Speed > 350:
  print("Audi Has Highest Speed")
  print("Audi Got: ", Maximum_Speed)
elif Maximum_Speed > 340:
  print("Volvo Has Highest Speed")
  print("Volvo Got: ", Maximum_Speed)
elif Maximum_Speed > 330:
  print("Lexus Has Highest Speed")
  print("Lexus Got: ", Maximum_Speed)
elif Maximum_Speed > 150:
  print("Mini Has Highest Speed")
  print("Mini Got: ", Maximum_Speed)
elif Maximum_Speed > 310:
  print("Jaguar Has Highest Speed")
  print("Jaguar Got: ", Maximum_Speed)
elif Maximum_Speed > 300:
  print("Ford Has Highest Speed")
  print("Ford Got: ", Maximum_Speed)
elif Maximum_Speed > 290:
  print("Chevrolet Has Highest Speed")
  print("Chevrolet Got: ", Maximum_Speed)
else:
  print("Normal Speed ")
# Out:
#  Enter Carola Car Speed: 200
#  Enter Honda Car Speed: 220
#  Enter Suzuki Car Speed: 150
#  Enter Toyota Car Speed: 250
#  Enter Mercedes Car Speed: 260
#  Enter Bughati Car Speed: 500
#  Enter Ferrari Car Speed: 450
#  Enter Lamborghini Car Speed: 400
#  Enter BMW Car Speed: 350
#  Enter Audi Car Speed: 300
#  Enter Volvo Car Speed: 280
#  Enter Lexus Car Speed: 250
#  Enter Mini Car Speed: 230
#  Enter Jaguar Car Speed: 270
#  Enter Ford Car Speed: 320
#  Enter Chevrolet Car Speed: 300
# Carola Has Highest Speed
# Carola Got:  2137.8999999999996

# %%
carola = int(input(" Enter Carola Car Speed: "))
honda = int(input(" Enter Honda Car Speed: "))
suzuki = int(input(" Enter Suzuki Car Speed: "))
toyota = int(input(" Enter Toyota Car Speed: "))
mercedes = int(input(" Enter Mercedes Car Speed: "))
bughati = int(input(" Enter Bughati Car Speed: "))
ferrari = int(input(" Enter Ferrari Car Speed: "))
lamborghini = int(input(" Enter Lamborghini Car Speed: "))
bmw = int(input(" Enter BMW Car Speed: "))
audi = int(input(" Enter Audi Car Speed: "))
volvo = int(input(" Enter Volvo Car Speed: "))
lexus = int(input(" Enter Lexus Car Speed: "))
mini = int(input(" Enter Mini Car Speed: "))
jaguar = int(input(" Enter Jaguar Car Speed: "))
ford = int(input(" Enter Ford Car Speed: "))
chevrolet = int(input(" Enter Chevrolet Car Speed: "))

carola_w1 = 0.1
honda_w2 = 0.11
suzuki_w3 = 0.2
toyota_w4 = 0.9
mercedes_w5 = 0.23
bughati_w6 = 0.99
ferrari_w7 = 0.67
lamb_w8 = 0.78
bmw_w9 = 0.45
audi_w10 = 0.34
volvo_w11 = 0.32
lexus_w12 = 0.25
mini_w13 = 0.3
jag_w14 = 0.34
ford_w15 = 0.2
chevrolet_w16 = 0.1

Maximum_Speed = (carola*carola_w1) + (honda*honda_w2) + (suzuki*suzuki_w3) + (toyota*toyota_w4) + (mercedes*mercedes_w5) + (bughati*bughati_w6) + (ferrari*ferrari_w7) + (lamborghini*lamb_w8) + (bmw*bmw_w9) + (audi*audi_w10) + (volvo*volvo_w11) + (lexus*lexus_w12) + (mini*mini_w13) + (jaguar*jag_w14) + (ford*ford_w15) + (chevrolet*chevrolet_w16)

if Maximum_Speed > 150:
  print("Carola Has Highest Speed")
  print("Carola Got: ", Maximum_Speed)
elif Maximum_Speed > 123:
  print("Honda Has Highest Speed")
  print("Honda Got: ", Maximum_Speed)
elif Maximum_Speed > 100:
  print("Suzuki Has Highest Speed")
  print("Suzuki Got: ", Maximum_Speed)
elif Maximum_Speed > 200:
  print("Toyota Has Highest Speed")
  print("Toyota Got: ", Maximum_Speed)
elif Maximum_Speed > 220:
  print("Mercedes Has Highest Speed")
  print("Mercedes Got: ", Maximum_Speed)
elif Maximum_Speed > 500:
  print("Bughati Has Highest Speed")
  print("Bughati Got: ", Maximum_Speed)
elif Maximum_Speed > 400:
  print("Ferrari Has Highest Speed")
  print("Ferrari Got: ", Maximum_Speed)
elif Maximum_Speed > 450:
  print("Lamborghini Has Highest Speed")
  print("Lamborghini Got: ", Maximum_Speed)
elif Maximum_Speed > 300:
  print("BMW Has Highest Speed")
  print("BMW Got: ", Maximum_Speed)
elif Maximum_Speed > 350:
  print("Audi Has Highest Speed")
  print("Audi Got: ", Maximum_Speed)
elif Maximum_Speed > 340:
  print("Volvo Has Highest Speed")
  print("Volvo Got: ", Maximum_Speed)
elif Maximum_Speed > 330:
  print("Lexus Has Highest Speed")
  print("Lexus Got: ", Maximum_Speed)
elif Maximum_Speed > 150:
  print("Mini Has Highest Speed")
  print("Mini Got: ", Maximum_Speed)
elif Maximum_Speed > 310:
  print("Jaguar Has Highest Speed")
  print("Jaguar Got: ", Maximum_Speed)
elif Maximum_Speed > 300:
  print("Ford Has Highest Speed")
  print("Ford Got: ", Maximum_Speed)
elif Maximum_Speed > 290:
  print("Chevrolet Has Highest Speed")
  print("Chevrolet Got: ", Maximum_Speed)
else:
  print("Normal Speed ")
# Out:
#  Enter Carola Car Speed: 200
#  Enter Honda Car Speed: 220
#  Enter Suzuki Car Speed: 150
#  Enter Toyota Car Speed: 250
#  Enter Mercedes Car Speed: 230
#  Enter Bughati Car Speed: 500
#  Enter Ferrari Car Speed: 400
#  Enter Lamborghini Car Speed: 450
#  Enter BMW Car Speed: 300
#  Enter Audi Car Speed: 280
#  Enter Volvo Car Speed: 230
#  Enter Lexus Car Speed: 220
#  Enter Mini Car Speed: 200
#  Enter Jaguar Car Speed: 290
#  Enter Ford Car Speed: 300
#  Enter Chevrolet Car Speed: 350
# Carola Has Highest Speed
# Carola Got:  2078.5

# %%
pencils = int(input("Enter Pencils Quantity: "))
pens = int(input("Enter Pens Quantity: "))
erasers = int(input("Enter Erasers Quantity: "))
markers = int(input("Enter Markers Quantity: "))
copies = int(input("Enter Copies Quantity: "))
notebooks = int(input("Enter Notebooks Quantity: "))
paper = int(input("Enter Paper Quantity: "))
sheets = int(input("Enter Sheets Quantity: "))
registers = int(input("Enter Registers Quantity: "))
pointers = int(input("Enter Pointers Quantity: "))
ballpoint = int(input("Enter Ballpoint Quantity: "))
shopners = int(input("Enter Shopners Quantity: "))
staplers = int(input("Enter Staplers Quantity: "))
paperclips = int(input("Enter Paperclips Quantity: "))
cover = int(input("Enter Cover Quantity: "))
books = int(input("Enter Books Quantity: "))
pencils = int(input("Enter Pencils Quantity: "))
holly_books = int(input("Enter Holly Books Quantity: "))
surah = int(input("Enter Surah Quantity: "))
ink = int(input("Enter Ink Quantity: "))

pencil_w1 = 0.9
pen_w2 = 0.1
eraser_w3 = 0.34
marker_w4 = 0.23
copy_w5 = 0.3
note_w6 = 0.45
pap_w7 = 0.12
shee_w8 = 0.4
reg_w9 = 0.18
poi_w10 = 0.2
bal_w11 = 0.6
sho_w12 = 0.8
sta_w13 = 0.5
p_w14 = 0.7
cover_w15 = 0.2
book_w16 = 0.34
pencils_w17 = 0.22
hol_w18 = 0.99
surah_w19 = 0.98
ink_w20 = 0.12

Stationaries = (pencils*pencil_w1) + (pens*pen_w2) + (erasers*eraser_w3) + (markers*marker_w4) + (copies*copy_w5) + (notebooks*note_w6) + (paper*pap_w7) + (sheets*shee_w8) + (registers*reg_w9) + (pointers*poi_w10) + (ballpoint*bal_w11) + (shopners*sho_w12) + (staplers*sta_w13) + (paperclips*p_w14) + (cover*cover_w15) + (books*book_w16) + (pencils*pencils_w17) + (holly_books*hol_w18) + (surah*surah_w19) + (ink*ink_w20)

if Stationaries > 90:
  print("Pencils Quantity is Maximum")
elif Stationaries > 80:
  print("Pens Quantity is Maximum")
elif Stationaries > 70:
  print("Erasers Quantity is Maximum")
elif Stationaries > 60:
  print("Markers Quantity is Maximum")
elif Stationaries > 50:
  print("Copies Quantity is Maximum")
elif Stationaries > 40:
  print("Notebooks Quantity is Maximum")
elif Stationaries > 30:
  print("Paper Quantity is Maximum")
elif Stationaries > 20:
  print("Sheets Quantity is Maximum")
elif Stationaries > 10:
  print("Registers Quantity is Maximum")
elif Stationaries > 16:
  print("Pointers Quantity is Maximum")
elif Stationaries > 15:
  print("Ballpoint Quantity is Maximum")
elif Stationaries > 56:
  print("Shopners Quantity is Maximum")
elif Stationaries > 78:
  print("Staplers Quantity is Maximum")
elif Stationaries > 23:
  print("Paperclips Quantity is Maximum")
elif Stationaries > 255:
  print("Cover Quantity is Maximum")
elif Stationaries > 22:
  print("Books Quantity is Maximum")
elif Stationaries > 98:
  print("Pencils Quantity is Maximum")
elif Stationaries > 99:
  print("Holly Books Quantity is Maximum")
elif Stationaries > 98:
  print("Surah Quantity is Maximum")
elif Stationaries > 97:
  print("Ink Quantity is Maximum")
else:
  print("No Quantity is Maximum")
# Out:
# Enter Pencils Quantity: 788
# Enter Pens Quantity: 746
# Enter Erasers Quantity: 999
# Enter Markers Quantity: 645
# Enter Copies Quantity: 233
# Enter Notebooks Quantity: 232
# Enter Paper Quantity: 344
# Enter Sheets Quantity: 653
# Enter Registers Quantity: 647
# Enter Pointers Quantity: 554
# Enter Ballpoint Quantity: 212
# Enter Shopners Quantity: 500
# Enter Staplers Quantity: 690
# Enter Paperclips Quantity: 677
# Enter Cover Quantity: 1000
# Enter Books Quantity: 646
# Enter Pencils Quantity: 230
# Enter Holly Books Quantity: 10000
# Enter Surah Quantity: 8232
# Enter Ink Quantity: 120
# Pencils Quantity is Maximum
