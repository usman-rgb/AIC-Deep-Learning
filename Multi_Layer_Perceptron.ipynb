# %%
#Multi_layer_perceptron



#Input layer
a1 = 0.4 # int(input("Enter a number has your input"))
a2 = 0.3 #
a3 = 0.7 #
a4 = 0.6 #


#HIDDEN LAYER 1-----------------------------------------------------------------
print("Hidden layer 2 Perceptrons")

#Weight of Layer 1 perceptron 1
w1_1_1 = 0.5
w1_1_2 = 0.10
w1_1_3 = 0.15
w1_1_4 = 0.20
w1_1_5 = 0.25

#Weight of Layer 1 perceptron 2
w1_2_6 = 0.30
w1_2_7 = 0.35
w1_2_8 = 0.40
w1_2_9 = 0.45
w1_2_10 = 0.50

#Weight of Layer 1 perceptron 3
w1_3_11 = 0.55
w1_3_12 = 0.60
w1_3_13 = 0.65
w1_3_14 = 0.70
w1_3_15 = 0.75

#Weight of Layer 1 perceptron 4
w1_4_16 = 0.80
w1_4_17 = 0.85
w1_4_18 = 0.90
w4_19 = 0.95
w1_4_20 = 1


#hidden_layer_1_perceptron_1
h1_c1 = (a1 * w1_1_1) + (a2 * w1_2_6) + (a3 * w1_3_11) + (a4 * w1_4_16)
print(f"hidden_layer_1_perceptron_1: {h1_c1}")

#hidden_Layer_1_perceptron_2
h1_c2 =  (a1 * w1_1_2) + (a2 * w1_2_7) + (a3 * w1_3_12) + (a4 * w1_4_17)
print(f"hidden_layer_2_perceptron_2: {h1_c2} ")

#hidden_Layer_1_perceptron_3
h1_c3 =  (a1 * w1_1_3) + (a2 * w1_2_8) + (a3 * w1_3_13) + (a4 * w1_4_18)
print(f"hidden_layer_1_perceptron_3: {h1_c3}")

#hidden_Layer_1_perceptron_4
h1_c4 =  (a1 * w1_1_4) + (a2 * w1_2_9) + (a3 * w1_3_14) + (a4 * w4_19)
print(f"hidden_layer_1_perceptron_4: {h1_c4}")

#hidden_Layer_1_perceptron_5
h1_c5 =  (a1 * w1_1_5) + (a2 * w1_2_10) + (a3 * w1_3_15) + (a4 * w1_4_20)
print(f"hidden_layer_1_perceptron_5: {h1_c5}")

#output_layer_3
final_result_layer1 = (h1_c1 + h1_c2 + h1_c3 + h1_c4 + h1_c5)
print(f"the final output of layer 1 is : {final_result_layer1}")

#HIDDEN LAYER 2-----------------------------------------------------------------

print("\nHidden player 2 Perceptrons")
#Weight of Layer 2 perceptron 1
w2_1_1 = 1.5
w2_1_2 = 1.10
w2_1_3 = 1.15
w2_1_4 = 1.20
w2_1_5 = 1.25

#Weight of Layer 2 perceptron 2
w2_2_6 = 1.30
w2_2_7 = 1.35
w2_2_8 = 1.40
w2_2_9 = 1.45
w2_2_10 = 1.50

#Weight of Layer 2 perceptron 3
w2_3_11 = 1.55
w2_3_12 = 1.60
w2_3_13 = 1.65
w2_3_14 = 1.70
w2_3_15 = 1.75

#Weight of Layer 2 perceptron 4
w2_4_16 = 1.80
w2_4_17 = 1.85
w2_4_18 = 1.90
w2_4_19 = 1.95
w2_4_20 = 2


#hidden_layer_2_perceptron_1
h2_c1 = (h1_c1 * w2_1_1) + (h1_c2 * w2_2_6) + (h1_c3 * w2_3_11) + (h1_c4 * w2_4_16)
print(f"hidden_layer_2_perceptron_1: {h2_c1}")

#hidden_Layer_2_perceptron_2
h2_c2 =  (h1_c1 * w2_1_2) + (h1_c2 * w2_2_7) + (h1_c3 * w2_3_12) + (h1_c4 * w2_4_17)
print(f"hidden_layer_2_perceptron_2: {h2_c2} ")

#hidden_Layer_2_perceptron_3
h2_c3 =  (h1_c1 * w2_1_3) + (h1_c2 * w2_2_8) + (h1_c3 * w2_3_13) + (h1_c4 * w2_4_18)
print(f"hidden_layer_2_perceptron_3: {h2_c3}")

#hidden_Layer_2_perceptron_4
h2_c4 =  (h1_c1 * w2_1_4) + (h1_c2 * w2_2_9) + (h1_c3 * w2_3_14) + (h1_c4 * w2_4_19)
print(f"hidden_layer_2_perceptron_4: {h2_c4}")

#hidden_Layer_2_perceptron_5
h2_c5 =  (h1_c1 * w2_1_5) + (h1_c2 * w2_2_10) + (h1_c3 * w2_3_15) + (h1_c4 * w2_4_20)
print(f"hidden_layer_2_perceptron_5: {h2_c5}")

#output_layer_2
final_result_layer2 = (h2_c1 + h2_c2 + h2_c3 + h2_c4 + h2_c5)
print(f"the final output of layer 2 is : {final_result_layer2}")

#HIDDEN LAYER 3 -----------------------------------------------------------------

print("\nHidden player 3 Perceptrons")
#Weight of Layer 3 perceptron 1
w3_1_1 = 2.5
w3_1_2 = 2.10
w3_1_3 = 2.15
w3_1_4 = 2.20
w3_1_5 = 2.25

#Weight of Layer 3 perceptron 2
w3_2_6 = 2.30
w3_2_7 = 2.35
w3_2_8 = 2.40
w3_2_9 = 2.45
w3_2_10 = 2.50

#Weight of Layer 3 perceptron 3
w3_3_11 = 2.55
w3_3_12 = 2.60
w3_3_13 = 2.65
w3_3_14 = 2.70
w3_3_15 = 2.75

#Weight of Layer 3 perceptron 4
w3_4_16 = 2.80
w3_4_17 = 2.85
w3_4_18 = 2.90
w3_4_19 = 2.95
w3_4_20 = 3


#hidden_layer_3_perceptron_1
h3_c1 = (h2_c1 * w3_1_1) + (h2_c2 * w3_2_6) + (h2_c3 * w3_3_11) + (h2_c4 * w3_4_16)
print(f"hidden_layer_3_perceptron_1: {h3_c1}")

#hidden_Layer_3_perceptron_2
h3_c2 =  (h2_c1 * w3_1_2) + (h2_c2 * w3_2_7) + (h2_c3 * w3_3_12) + (h2_c4 * w3_4_17)
print(f"hidden_layer_3_perceptron_2: {h3_c2} ")

#hidden_Layer_3_perceptron_3
h3_c3 =  (h2_c1 * w3_1_3) + (h2_c2 * w3_2_8) + (h2_c3 * w3_3_13) + (h2_c4 * w3_4_18)
print(f"hidden_layer_3_perceptron_3: {h3_c3}")

#hidden_Layer_3_perceptron_4
h3_c4 =  (h2_c1 * w3_1_4) + (h2_c2 * w3_2_9) + (h2_c3 * w3_3_14) + (h2_c4 * w3_4_19)
print(f"hidden_layer_3_perceptron_4: {h3_c4}")

#hidden_Layer_3_perceptron_5
h3_c5 =  (h2_c1 * w3_1_5) + (h2_c2 * w3_2_10) + (h2_c3 * w3_3_15) + (h2_c4 * w3_4_20)
print(f"hidden_layer_3_perceptron_5: {h3_c5}")

#<---------------------------------------------------------------------------------------------->
#output_layer_3
final_result_layer3 = (h3_c1 + h3_c2 + h3_c3 + h3_c4 + h3_c5)
print(f"the final output of layer 3 is : {final_result_layer3}")
# Out:
# Hidden layer 2 Perceptrons
# hidden_layer_1_perceptron_1: 1.155
# hidden_layer_2_perceptron_2: 1.075
# hidden_layer_1_perceptron_3: 1.175
# hidden_layer_1_perceptron_4: 1.275
# hidden_layer_1_perceptron_5: 1.375
# the final output of layer 1 is : 6.055
#
# Hidden player 2 Perceptrons
# hidden_layer_2_perceptron_1: 7.24625
# hidden_layer_2_perceptron_2: 6.9605
# hidden_layer_2_perceptron_3: 7.1945
# hidden_layer_2_perceptron_4: 7.4285
# hidden_layer_2_perceptron_5: 7.6625
# the final output of layer 2 is : 36.49225
#
# Hidden player 3 Perceptrons
# hidden_layer_3_perceptron_1: 73.27054999999999
# hidden_layer_3_perceptron_2: 71.451225
# hidden_layer_3_perceptron_3: 72.89271249999999
# hidden_layer_3_perceptron_4: 74.33420000000001
# hidden_layer_3_perceptron_5: 75.7756875
# the final output of layer 3 is : 367.724375

# %%
Healthcare = float(input("Enter healthcare expenditure (in billions): "))
Education = float(input("Enter education expenditure (in billions): "))
Infrastructure = float(input("Enter infrastructure expenditure (in billions): "))
Defense = float(input("Enter defense expenditure (in billions): "))
Agriculture = float(input("Enter agriculture expenditure (in billions): "))

# Hidden Layer 1 ------------------------------------------------------------------------------------

print(" Hidden Layer 1 Perceptrone ")
# Node 1-------------------

w1_1_1 = 0.4   # Healthcare to Perceptron 1 weight
w1_1_2 =0.5    # Education to Perceptron 1 weight
w1_1_3 = 0.8   # Infrastructure to Perceptron 1 weight
w1_1_4 = 0.7   # Defense to Perceptron 1 weight
w1_1_5 = 0.9   # Agriculture to Perceptron 1 weight

# Node 2-------------------

w1_2_1 = 0.45   # Healthcare to Perceptron 2 weight
w1_2_2 = 0.34   # Education to Perceptron 2 weight
w1_2_3 = 0.9    # Infrastructure to Perceptron 2 weight
w1_2_4 = 0.78   # Defense to Perceptron 2 weight
w1_2_5 = 0.5    # Agriculture to Perceptron 2 weight

# Node 3-------------------

w1_3_1 = 0.65    # Healthcare to Perceptron 3 weight
w1_3_2 = 0.76    # Education to Perceptron 3 weight
w1_3_3 = 0.5     # Infrastructure to Perceptron 3 weight
w1_3_4 = 0.4   # Defense to Perceptron 3 weight
w1_3_5 = 0.9     # Agriculture to Perceptron 3 weight

# Node 4-------------------

w1_4_1 = 0.8     # Healthcare to Perceptron 4 weight
w1_4_2 = 0.4     # Education to Perceptron 4 weight
w1_4_3 = 0.56   # Infrastructure to Perceptron 4 weight
w1_4_4 = 0.45   # Defense to Perceptron 4 weight
w1_4_5 = 0.2    # Agriculture to Perceptron 4 weight

# Node 5-------------------

w1_5_1 = 0.5    # Healthcare to Perceptron 5 weight
w1_5_2 = 0.4    # Education to Perceptron 5 weight
w1_5_3 = 0.4    # Infrastructure to Perceptron 5 weight
w1_5_4 = 0.34   # Defense to Perceptron 5 weight
w1_5_5 = 0.3    # Agriculture to Perceptron 5 weight

# Perceptrone 1 Calculation for Hidden Layer 1

hiden1_calculation = (Healthcare*w1_1_1) + (Education*w1_2_1) + (Infrastructure*w1_3_1) + (Defense*w1_4_1) + (Agriculture*w1_5_1)
print(f"Hidden Layer 1 Perceptron 1: {hiden1_calculation}")

# Perceptrone 2 Calculation for Hidden Layer 1

hiden2_calculation = (Healthcare*w1_1_2) + (Education*w1_2_2) + (Infrastructure*w1_3_2) + (Defense*w1_4_2) + (Agriculture*w1_5_2)
print(f"Hidden Layer 1 Perceptron 2: {hiden2_calculation}")

# Perceptrone 3 Calculation for Hidden Layer 1

hiden3_calculation = (Healthcare*w1_1_3) + (Education*w1_2_3) + (Infrastructure*w1_3_3) + (Defense*w1_4_3) + (Agriculture*w1_5_3)
print(f"Hidden Layer 1 Perceptron 3: {hiden3_calculation}")

# Perceptrone 4 Calculation for Hidden Layer 1

hiden4_calculation = (Healthcare*w1_1_4) + (Education*w1_2_4) + (Infrastructure*w1_3_4) + (Defense*w1_4_4) + (Agriculture*w1_5_4)
print(f"Hidden Layer 1 Perceptron 4: {hiden4_calculation}")

# Perceptrone 5 Calculation for Hidden Layer 1

hiden5_calculation = (Healthcare*w1_1_5) + (Education*w1_2_5) + (Infrastructure*w1_3_5) + (Defense*w1_4_5) + (Agriculture*w1_5_5)
print(f"Hidden Layer 1 Perceptron 5: {hiden5_calculation}")

final_result_layer1 = (hiden1_calculation + hiden2_calculation + hiden3_calculation + hiden4_calculation + hiden5_calculation)
print(f"Final output of Hidden Layer 1: {final_result_layer1}")

# Hidden Layer 2 ----------------------------------------------

print(" Hidden Layer 2 Perceptrone ")
# Node 1-------------------

w2_1_1 = 0.47   # Healthcare to Perceptron 1 weight
w2_1_2 =0.57    # Education to Perceptron 1 weight
w2_1_3 = 0.80   # Infrastructure to Perceptron 1 weight
w2_1_4 = 0.74   # Defense to Perceptron 1 weight
w2_1_5 = 0.56   # Agriculture to Perceptron 1 weight

# Node 2-------------------

w2_2_1 = 0.45   # Healthcare to Perceptron 2 weight
w2_2_2 = 0.34   # Education to Perceptron 2 weight
w2_2_3 = 0.91    # Infrastructure to Perceptron 2 weight
w2_2_4 = 0.78   # Defense to Perceptron 2 weight
w2_2_5 = 0.54    # Agriculture to Perceptron 2 weight

# Node 3-------------------

w2_3_1 = 0.65    # Healthcare to Perceptron 3 weight
w2_3_2 = 0.76    # Education to Perceptron 3 weight
w2_3_3 = 0.58     # Infrastructure to Perceptron 3 weight
w2_3_4 = 0.42   # Defense to Perceptron 3 weight
w2_3_5 = 0.94     # Agriculture to Perceptron 3 weight

# Node 4-------------------

w2_4_1 = 0.80     # Healthcare to Perceptron 4 weight
w2_4_2 = 0.43     # Education to Perceptron 4 weight
w2_4_3 = 0.56   # Infrastructure to Perceptron 4 weight
w2_4_4 = 0.45   # Defense to Perceptron 4 weight
w2_4_5 = 0.29   # Agriculture to Perceptron 4 weight

# Node 5-------------------

w2_5_1 = 0.58    # Healthcare to Perceptron 5 weight
w2_5_2 = 0.43   # Education to Perceptron 5 weight
w2_5_3 = 0.44   # Infrastructure to Perceptron 5 weight
w2_5_4 = 0.34   # Defense to Perceptron 5 weight
w2_5_5 = 0.31   # Agriculture to Perceptron 5 weight

hiden_layer2_calculation1 = (hiden1_calculation * w2_1_1) + (hiden2_calculation * w2_2_1) + (hiden3_calculation * w2_3_1) + (hiden4_calculation * w2_4_1) + (hiden5_calculation * w2_5_1)
print(f"Hidden Layer 2 Perceptron 1: {hiden_layer2_calculation1}")

hiden_layer2_calculation2 = (hiden1_calculation * w2_1_2) + (hiden2_calculation*w2_2_2) + (hiden3_calculation * w2_3_2) + (hiden4_calculation * w2_4_2) + (hiden5_calculation * w2_5_2)
print(f"Hidden Layer 2 Perceptron 2: {hiden_layer2_calculation2}")

hiden_layer2_calculation3 = (hiden1_calculation * w2_1_3) + (hiden2_calculation * w2_2_3) + (hiden3_calculation * w2_3_3) + (hiden4_calculation * w2_4_3) + (hiden5_calculation * w2_5_3)
print(f"Hidden Layer 2 Perceptron 3: {hiden_layer2_calculation3}")

hiden_layer2_calculation4 = (hiden1_calculation * w2_1_4) + (hiden2_calculation * w2_2_4) + (hiden3_calculation * w2_3_4) + (hiden4_calculation * w2_4_4) + (hiden5_calculation*w2_5_4)
print(f"Hidden Layer 2 Perceptron 4: {hiden_layer2_calculation4}")

hiden_layer2_calculation5 = (hiden1_calculation * w2_1_5) + (hiden2_calculation * w2_2_5) + (hiden3_calculation * w2_3_5) + (hiden4_calculation * w2_4_5) + (hiden5_calculation*w2_5_5)
print(f"Hidden Layer 2 Perceptron 5: {hiden_layer2_calculation5}")

final_result_layer2 = (hiden_layer2_calculation1 + hiden_layer2_calculation2 + hiden_layer2_calculation3 + hiden_layer2_calculation4 + hiden_layer2_calculation5)

# Final Government Budget (simulated)
government_budget = final_result_layer2
print(f"Simulated Government Annual Budget: {government_budget} billion")
# Out:
# Enter healthcare expenditure (in billions): 0.5
# Enter education expenditure (in billions): 0.3
# Enter infrastructure expenditure (in billions): 0.7
# Enter defense expenditure (in billions): 0.6
# Enter agriculture expenditure (in billions): 0.9
#  Hidden Layer 1 Perceptrone
# Hidden Layer 1 Perceptron 1: 1.72
# Hidden Layer 1 Perceptron 2: 1.484
# Hidden Layer 1 Perceptron 3: 1.7160000000000002
# Hidden Layer 1 Perceptron 4: 1.44
# Hidden Layer 1 Perceptron 5: 1.62
# Final output of Hidden Layer 1: 7.9799999999999995
#  Hidden Layer 2 Perceptrone
# Hidden Layer 2 Perceptron 1: 4.683199999999999
# Hidden Layer 2 Perceptron 2: 4.104920000000001
# Hidden Layer 2 Perceptron 3: 5.240920000000001
# Hidden Layer 2 Perceptron 4: 4.34984
# Hidden Layer 2 Perceptron 5: 4.2974000000000006
# Simulated Government Annual Budget: 22.676280000000002 billion
